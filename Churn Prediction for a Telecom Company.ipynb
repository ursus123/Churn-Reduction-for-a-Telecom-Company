# %% [markdown]
# ## Churn Prediction

# %% [markdown]
# ### 1. Importing Libraries

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')
import missingno as msn
import seaborn as sns

from tpot import TPOTClassifier
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_validate
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# The main purpose of this project is to build a predictive model of who will churn or who won't churn in order to understand what really drives people to churn so at the the end we might find impactful insights on how to lower the churn rate

# %% [markdown]
# ### 2.Data Wrangling

# %% [markdown]
# #### 2.1. Importing the data

# %%
# Importing the telecom dataset
data=pd.read_csv('telecom.csv')
data.head(3)
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
# 2             41.38  ...              110             10.30
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
#
#    customer service calls  churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
#
# [3 rows x 21 columns]

# %%
# Importing US states dataset
us_states=pd.read_csv('state-abbrevs.csv')
us_states.head(3)
# Out:
#      state abbreviation
# 0  Alabama           AL
# 1   Alaska           AK
# 2  Arizona           AZ

# %% [markdown]
# #### 2.2. Data Exploration

# %%
# Data Columns
data.columns
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %%
# Data Shape
data.shape
# Out:
# (3333, 21)

# %%
# Data type
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
#  14  total night calls       3333 non-null   int64
#  15  total night charge      3333 non-null   float64
#  16  total intl minutes      3333 non-null   float64
#  17  total intl calls        3333 non-null   int64
#  18  total intl charge       3333 non-null   float64
#  19  customer service calls  3333 non-null   int64
#  20  churn                   3333 non-null   bool
# dtypes: bool(1), float64(8), int64(8), object(4)
# memory usage: 524.2+ KB

# %%
# Checking Null Values (1)
msn.matrix(data);
## No Null values

# %%
## Checking Null Values (2)
data.isna().sum()
# Out:
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %%
# Data description
data.describe().T
# Out:
#                          count        mean        std     min     25%     50%  \
# account length          3333.0  101.064806  39.822106    1.00   74.00  101.00
# area code               3333.0  437.182418  42.371290  408.00  408.00  415.00
# number vmail messages   3333.0    8.099010  13.688365    0.00    0.00    0.00
# total day minutes       3333.0  179.775098  54.467389    0.00  143.70  179.40
# total day calls         3333.0  100.435644  20.069084    0.00   87.00  101.00
# total day charge        3333.0   30.562307   9.259435    0.00   24.43   30.50
# total eve minutes       3333.0  200.980348  50.713844    0.00  166.60  201.40
# total eve calls         3333.0  100.114311  19.922625    0.00   87.00  100.00
# total eve charge        3333.0   17.083540   4.310668    0.00   14.16   17.12
# total night minutes     3333.0  200.872037  50.573847   23.20  167.00  201.20
# total night calls       3333.0  100.107711  19.568609   33.00   87.00  100.00
# total night charge      3333.0    9.039325   2.275873    1.04    7.52    9.05
# total intl minutes      3333.0   10.237294   2.791840    0.00    8.50   10.30
# total intl calls        3333.0    4.479448   2.461214    0.00    3.00    4.00
# total intl charge       3333.0    2.764581   0.753773    0.00    2.30    2.78
# customer service calls  3333.0    1.562856   1.315491    0.00    1.00    1.00
#
#                            75%     max
# account length          127.00  243.00
# area code               510.00  510.00
# number vmail messages    20.00   51.00
# total day minutes       216.40  350.80
# total day calls         114.00  165.00
# total day charge         36.79   59.64
# total eve minutes       235.30  363.70
# total eve calls         114.00  170.00
# total eve charge         20.00   30.91
# total night minutes     235.30  395.00
# total night calls       113.00  175.00
# total night charge       10.59   17.77
# total intl minutes       12.10   20.00
# total intl calls          6.00   20.00
# total intl charge         3.27    5.40
# customer service calls    2.00    9.00

# %% [markdown]
# ### 3. Explaratory Data Analysis

# %% [markdown]
# #### 3.1 States and Churn

# %%
# Making a list of us states names to be used later
us_states=us_states.sort_values('abbreviation')
list_state=list(us_states['state'])

# %%
# Making a new dataset to analyze churn percentage in each state
states_churn=pd.crosstab(data['state'],data['churn'])
states_churn['Total People']=states_churn[False]+states_churn[True]
states_churn['churn_percentage']=round((states_churn[True]*100)/states_churn['Total People'],2)
states_churn=states_churn.sort_values('state')
states_churn['state_names']=list_state
states_churn=states_churn[['state_names',False,True,'Total People','churn_percentage']]
states_churn.head(5)
# Out:
# churn state_names  False  True  Total People  churn_percentage
# state
# AK         Alaska     49     3            52              5.77
# AL        Alabama     72     8            80             10.00
# AR       Arkansas     44    11            55             20.00
# AZ        Arizona     60     4            64              6.25
# CA     California     25     9            34             26.47

# %%
# Top 10 states with a high percentage of churning
first_top10=states_churn.sort_values('churn_percentage', ascending=False).head(10)
first_top10
# Out:
# churn     state_names  False  True  Total People  churn_percentage
# state
# NJ         New Jersey     50    18            68             26.47
# CA         California     25     9            34             26.47
# TX              Texas     54    18            72             25.00
# MD           Maryland     53    17            70             24.29
# SC     South Carolina     46    14            60             23.33
# MI           Michigan     57    16            73             21.92
# MS        Mississippi     51    14            65             21.54
# NV             Nevada     52    14            66             21.21
# WA         Washington     52    14            66             21.21
# ME              Maine     49    13            62             20.97

# %%
# Top 10 states with a low percentage of churning
last_top10=states_churn.sort_values('churn_percentage', ascending=True).head(10)
last_top10
# Out:
# churn   state_names  False  True  Total People  churn_percentage
# state
# HI           Hawaii     50     3            53              5.66
# AK           Alaska     49     3            52              5.77
# AZ          Arizona     60     4            64              6.25
# VA         Virginia     72     5            77              6.49
# IA             Iowa     41     3            44              6.82
# LA        Louisiana     47     4            51              7.84
# NE         Nebraska     56     5            61              8.20
# IL         Illinois     53     5            58              8.62
# WI        Wisconsin     71     7            78              8.97
# RI     Rhode Island     59     6            65              9.23

# %%
# Churn rate in each state
states_churn[['state_names','churn_percentage']].sort_values(by='churn_percentage').plot(kind='barh', figsize=(15,12), title='Churn Percentage in each state');

# %%
# Total people that uses the line for states with a high percentage of churns and those with low percentage of churn
(sum(first_top10['Total People']),sum(last_top10['Total People']))
## The total number of lines in each of these categories is almost the same
# Out:
# (636, 603)

# %%
# Average of churn percentage for states with high probality of churn and those with low probability of churn
(round(first_top10['churn_percentage'].mean(),2),round(last_top10['churn_percentage'].mean(),2))
# Out:
# (23.24, 7.39)

# %% [markdown]
# **Conclusion_1**:
# - Many people will suggest that the more the lines that are used the more churn rate
# - But by looking at the graph and tables we see that the total number of people that uses the line does not have a big impact on churn rate for example **Mississippi** and **Rhode Island** has the same number of people who uses this telecom company but these two states are completely on different sides when it comes to churn percentage.
#
# - By focusing on those states with low churn the company will be reducing the churn rate up to 15% since by having a lot number people that uses the line is not really a big factor that drives the churn rate

# %% [markdown]
# #### 3.2. Churn

# %%
# Percentage of people who churn
data.groupby('churn')['phone number'].count().plot(kind='pie', autopct='%.2f',figsize=(8,8));
plt.title('Percentage of People who churned');
## Almost 15% of all phone numbers churn

# %%
# Churn and minutes
churn_minutes=data.groupby('churn')[['total day minutes','total eve minutes','total night minutes']].mean()
churn_minutes['Total']=churn_minutes['total day minutes']+churn_minutes['total eve minutes']+churn_minutes['total night minutes']
churn_minutes
## we can see that peole who churn spend more minutes on calls on average more than those who did not churn
# Out:
#        total day minutes  total eve minutes  total night minutes       Total
# churn
# False         175.175754         199.043298           200.133193  574.352246
# True          206.914079         212.410145           205.231677  624.555901

# %%
churn_minutes['Total'].plot(kind='bar', title='churn & minutes');

# %%
# Churn and number of calls
churn_calls=data.groupby('churn')[['total day calls','total eve calls','total night calls']].mean()
churn_calls['Total']=churn_calls['total day calls']+churn_calls['total eve calls']+churn_calls['total night calls']
churn_calls
## The number of calls on average are almost the same but still the average number of calls a person who churns is 
## still  higher than the person who did not churn
# Out:
#        total day calls  total eve calls  total night calls       Total
# churn
# False       100.283158       100.038596         100.058246  300.380000
# True        101.335404       100.561077         100.399586  302.296066

# %%
churn_calls['Total'].plot(kind='bar', title='churn & calls');

# %%
# churn and charges
churn_charges=data.groupby('churn')[['total day charge','total eve charge','total night charge']].mean()
churn_charges['Total']=churn_charges['total day charge']+churn_charges['total eve charge']+churn_charges['total night charge']
churn_charges
## People who churn are charged more on average more than people who do not especially during the day
# Out:
#        total day charge  total eve charge  total night charge      Total
# churn
# False         29.780421         16.918909            9.006074  55.705404
# True          35.175921         18.054969            9.235528  62.466418

# %%
churn_charges['Total'].plot(kind='bar', title='churn & charges');

# %%
# Churn and International Services
churn_international=data.groupby('churn')[['total intl minutes','total intl calls','total intl charge']].mean()
churn_international
## People who churn get almost the same international services as people who do not.But people who do not churn still have
## a higher number
# Out:
#        total intl minutes  total intl calls  total intl charge
# churn
# False           10.158877          4.532982           2.743404
# True            10.700000          4.163561           2.889545

# %%
churn_international.plot(kind='pie',subplots=True, figsize=(18,6),autopct='%.2f', title='Churn and International services');

# %%
# Churn and number of Voicemails
churn_voicemails=data.groupby('churn')['number vmail messages'].mean()
churn_voicemails
## People who do not churn receive more voice messages than those who churn
# Out:
# churn
# False    8.604561
# True     5.115942
# Name: number vmail messages, dtype: float64

# %% [markdown]
# **Conclusion_2**:
# - Looking at the tables above we see that the numbers are almost the same but the numbers of people who churn are a little bit higher than those of who do not churn. People who churn spent more minutes on average more than those who did not churn,they had more number of calls and even more international minutes.
# - The only time where people who do not churn has a bigger number is the total number of international calls by 52% of all calls and the number of voice mail messages.
# - There could be many reasons but lets first see the average account length of these two categories (the people who churn and those who did not churn)

# %%
churn_account_length=round(data.groupby('churn')['account length'].mean(),1)
churn_account_length
# Out:
# churn
# False    100.8
# True     102.7
# Name: account length, dtype: float64

# %% [markdown]
# **Conclusion_3**:
# - It is possible that because people who churn have longer account length (integer value, how long the account have been active) had an impact on them having a hihger number of  total  minutes, calls, charges and international services than people did not churn

# %%
# churn & international plan
pd.crosstab(data['churn'], data['international plan'])
# Out:
# international plan    no  yes
# churn
# False               2664  186
# True                 346  137

# %%
pd.crosstab(data['international plan'], data['churn']).plot(kind='bar', title= 'churn & international plan');

# %%
# churn and voice mail plan
pd.crosstab(data['voice mail plan'], data['churn'])
# Out:
# churn            False  True
# voice mail plan
# no                2008    403
# yes                842     80

# %%
pd.crosstab(data['voice mail plan'], data['churn']).plot(kind='bar', title= 'churn & voice mail plan');

# %%
# churn & area code
pd.crosstab(data['area code'], data['churn'])
# Out:
# churn      False  True
# area code
# 408          716    122
# 415         1419    236
# 510          715    125

# %%
pd.crosstab(data['area code'], data['churn']).plot(kind='bar', title='churn & area code');

# %%
# churn and the number of customer services calls
churn_customer_service_calls=round(data.groupby('churn')['customer service calls'].mean(),2)
churn_customer_service_calls
# Out:
# churn
# False    1.45
# True     2.23
# Name: customer service calls, dtype: float64

# %%
churn_customer_service_calls.plot(kind='pie', autopct='%.2f',figsize=(5,5), title='churn and the number of customer services calls');

# %% [markdown]
# ### 4. Feature Engineering

# %%
df=data.copy()

# %%
# Replacing state abbreviations with integers
num1_num51=np.arange(1,52)
list_state2=list(np.sort(df['state'].unique()))
df['state'].replace(list_state2,num1_num51, inplace=True)

# %%
# Replacing area codes with integers
list_area_code=list(df['area code'].unique())
df['area code'].replace(list_area_code,[1,2,3], inplace=True)

# %%
#Replacing international plan with integers
df['international plan'].replace(['no','yes'],[0,1], inplace=True)

# %%
#Replacing voice mail plan with integers
df['voice mail plan'].replace(['yes','no'],[1,0], inplace=True)

# %%
# Replacing churn with integers
df['churn'].replace([False,True],[0,1], inplace=True)

# %%
df.head(5)
# Out:
#    state  account length  area code phone number  international plan  \
# 0     17             128          1     382-4657                   0
# 1     36             107          1     371-7191                   0
# 2     32             137          1     358-1921                   0
# 3     36              84          2     375-9999                   1
# 4     37              75          1     330-6626                   1
#
#    voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0                1                     25              265.1              110
# 1                1                     26              161.6              123
# 2                0                      0              243.4              114
# 3                0                      0              299.4               71
# 4                0                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
# 2             41.38  ...              110             10.30
# 3             50.90  ...               88              5.26
# 4             28.34  ...              122             12.61
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    customer service calls  churn
# 0                       1      0
# 1                       1      0
# 2                       0      0
# 3                       2      0
# 4                       3      0
#
# [5 rows x 21 columns]

# %% [markdown]
# #### 4.1 Feature Correlation

# %%
#Feature Correlation
plt.figure(figsize=(15,12))
sns.heatmap(df.corr());

# %% [markdown]
# **customer service calls vs churn**

# %%
sns.relplot(x='customer service calls',y='customer service calls', hue='churn',data=data);

# %% [markdown]
# **total day charge vs churn**

# %%
sns.relplot(x='total day charge',y='total day charge', hue='churn',data=data);

# %% [markdown]
# From this heatmap we see that features like *customer service calls, international plan, today day minutes, today day charge* are somehow correlated with churn

# %% [markdown]
# ### 5. Pre_Processing and Processing

# %%
# 5.1 Defining the Target
X=df[['state','account length','area code','international plan', 'voice mail plan', 'number vmail messages',
       'total day minutes', 'total day calls', 'total day charge',
       'total eve minutes', 'total eve calls', 'total eve charge',
       'total night minutes', 'total night calls', 'total night charge',
       'total intl minutes', 'total intl calls', 'total intl charge',
       'customer service calls']]
y=df['churn']

# %%
# 5.2 Splitting the data
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25, random_state=2)

# %%
X_train
# Out:
#       state  account length  area code  international plan  voice mail plan  \
# 1174      5              72          2                   0                1
# 119      14              97          2                   0                0
# 3133      7             147          1                   0                0
# 1635      4              66          3                   0                0
# 1888     48             117          2                   0                0
# ...     ...             ...        ...                 ...              ...
# 2347     15              68          1                   1                1
# 1608     38             163          2                   0                1
# 2541     18              73          2                   0                0
# 2575     26             131          1                   0                0
# 3240     42              34          2                   0                0
#
#       number vmail messages  total day minutes  total day calls  \
# 1174                     39               92.8               98
# 119                       0              239.8              125
# 3133                      0              124.4               74
# 1635                      0              154.0              133
# 1888                      0              191.1               93
# ...                     ...                ...              ...
# 2347                     29              195.5              113
# 1608                     25              219.6               99
# 2541                      0               94.9              121
# 2575                      0              131.6               95
# 3240                      0              180.6               65
#
#       total day charge  total eve minutes  total eve calls  total eve charge  \
# 1174             15.78              271.2              115             23.05
# 119              40.77              214.8              111             18.26
# 3133             21.15              320.9               78             27.28
# 1635             26.18              198.9              121             16.91
# 1888             32.49              282.8               56             24.04
# ...                ...                ...              ...               ...
# 2347             33.24              171.6               96             14.59
# 1608             37.33              210.4               99             17.88
# 2541             16.13              253.2               83             21.52
# 2575             22.37              179.3              109             15.24
# 3240             30.70              280.4               99             23.83
#
#       total night minutes  total night calls  total night charge  \
# 1174                167.1                 83                7.52
# 119                 143.3                 81                6.45
# 3133                157.2                126                7.07
# 1635                151.9                100                6.84
# 1888                 84.8                118                3.82
# ...                   ...                ...                 ...
# 2347                204.0                 85                9.18
# 1608                242.7                 88               10.92
# 2541                175.1                 86                7.88
# 2575                251.2                129               11.30
# 3240                292.4                105               13.16
#
#       total intl minutes  total intl calls  total intl charge  \
# 1174                 5.8                 7               1.57
# 119                  8.7                 5               2.35
# 3133                10.4                 4               2.81
# 1635                 9.5                 3               2.57
# 1888                12.0                 4               3.24
# ...                  ...               ...                ...
# 2347                13.5                 9               3.65
# 1608                13.8                 8               3.73
# 2541                14.2                 2               3.83
# 2575                15.5                 3               4.19
# 3240                 5.0                 3               1.35
#
#       customer service calls
# 1174                       1
# 119                        2
# 3133                       2
# 1635                       4
# 1888                       2
# ...                      ...
# 2347                       1
# 1608                       2
# 2541                       2
# 2575                       1
# 3240                       1
#
# [2499 rows x 19 columns]

# %%
#Training the algorithm
tpot= TPOTClassifier(generations=1,verbosity=2,random_state=42)
tpot.fit(X_train,y_train)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Optimization Progress', max=200.0, style=ProgressStyle(de…
# Generation 1 - Current best internal CV score: 0.9527783567134268
#
# Best pipeline: ExtraTreesClassifier(input_matrix, bootstrap=True, criterion=gini, max_features=1.0, min_samples_leaf=1, min_samples_split=4, n_estimators=100)
# TPOTClassifier(generations=1, random_state=42, verbosity=2)

# %%
#Fitting and training the model
model=ExtraTreesClassifier(n_estimators=250,random_state=0)
model.fit(X_train,y_train)
# Out:
# ExtraTreesClassifier(n_estimators=250, random_state=0)

# %%
# The score on the Test dataset
model.score(X_test,y_test)
# Out:
# 0.9364508393285371

# %%
# Feature importance
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(100).plot(kind='barh', title='Feature Importance', figsize=(10,7));

# %% [markdown]
# ### 6. Modeling and Final Insights

# %% [markdown]
# #### 6.1 **We know that 14.5% percentage of all lines churn and the predicted churn is at 13%**

# %%
y_pred=pd.Series(model.predict(X))

# %%
y_pred.value_counts().plot(kind='pie', autopct='%.2f');

# %%
df['churn'].value_counts().plot(kind='pie', autopct='%.2f');

# %% [markdown]
# _________________________________________________________________________________________

# %% [markdown]
# #### 6.2 **Using only the training dataset people who churn are at 14.7% which is the same as the predicted churn**

# %%
y_pred1=pd.Series(model.predict(X_train))

# %%
y_pred1.value_counts().plot(kind='pie', autopct='%.2f');

# %%
y_train.value_counts().plot(kind='pie', autopct='%.2f');

# %% [markdown]
# ___________________________________________________________________________________________________

# %% [markdown]
# #### 6.3 **Using the test dataset people who churn are at 14% and the predicted churn is at 8%**

# %%
y_pred2=pd.Series(model.predict(X_test))

# %%
y_pred2.value_counts().plot(kind='pie', autopct='%.2f');

# %%
y_test.value_counts().plot(kind='pie',autopct='%.2f');

# %% [markdown]
# ____________________________________________________________________________________________

# %% [markdown]
# #### 6.4 Test Score and Absolute mean error

# %%
#Cross validation
cv= cross_validate(model, X,y, scoring='neg_mean_absolute_error', cv=10, n_jobs=-1)
cv['test_score']
# Out:
# array([-0.06586826, -0.07784431, -0.06586826, -0.07807808, -0.05405405,
#        -0.04504505, -0.06606607, -0.07807808, -0.06306306, -0.06606607])

# %%
# Absolute mean error
abs_mean_err=np.mean(-1*cv['test_score'])
abs_mean_err
# Out:
# 0.06600312887738037

# %% [markdown]
# With a predicted churn percentage of 13% and the actual churn percentage of 14.5% and an absolute error of 0.066 it shows there is room for improvement

# %% [markdown]
# #### 6.5 Insights

# %%
#total day minutes and total day charge
plt.title('total day minutes and total day charge')
sns.scatterplot(y='total day charge',x='total day minutes', hue='churn',data=data);

# %% [markdown]
# We can see that total day minutes and total day charge are highly correlated and many people who churn actually have spend more money and more minutes on their plans

# %%
#total day minutes and international plan
plt.title('total day minutes and international plan')
sns.scatterplot(y='total day minutes',x='international plan',hue='churn',data=data);

# %%
plt.title('total day charge and international plan')
sns.scatterplot(y='total day charge',x='international plan', hue='churn',data=data);

# %% [markdown]
# - With these 2 figures above we see that people with international plans churn alot.
# - Taking into consideration the pie chart below we see that 42% of people who have international plans actually churn

# %%
pd.crosstab(df['international plan'],df['churn']).loc[1,:].plot(kind='pie', autopct='%.2f');

# %% [markdown]
# It will reduce the churn percentage if we reduce the number of international plans offered

# %%
# Customer Service calls and churn
plt.title('total day minutes and customer service calls')
sns.scatterplot(y='total day minutes',x='customer service calls', hue='churn',data=data);

# %%
plt.title('total day charge and customer service calls')
sns.scatterplot(y='total day charge',x='customer service calls', hue='churn',data=data);

# %% [markdown]
# These above figures shows that customer service calls above 3 have a big impact on churning

# %% [markdown]
# #### 6.4 Further Insights

# %%
#Replacing all values with 4+ customer service calls by 3
X_=X.copy()
X_['customer service calls'].replace([4, 5, 7, 9, 6, 8],[3,3,3,3,3,3], inplace=True)

# %%
y_pred_=pd.Series(model.predict(X_))

# %%
y_pred_.value_counts().plot(kind='pie', autopct='%.2f');

# %% [markdown]
# Making 3 as the maximum customer service calls a person will receive will reduce the churn percentage from 13% up to 10.62% which is reduction of 2.4%

# %%
#Removing all international plans
X__=X.copy()
X__['international plan'].replace(1,0, inplace=True)

# %%
y_pred__=pd.Series(model.predict(X__))

# %%
y_pred__.value_counts().plot(kind='pie', autopct='%.2f');

# %% [markdown]
# Removing International plans for everybody (regardless of international minutes and international plans) will reduce the churn percentage up to 10.05% thats a 3% decrease

# %%
# Reducing Customer service calls and Removing all international plans
X_['international plan'].replace(1,0, inplace=True)

# %%
y_pred_1=pd.Series(model.predict(X_))

# %%
y_pred_1.value_counts().plot(kind='pie', autopct='%.2f');

# %% [markdown]
# - Removing all international plans and reducing the number of customer service calls can reduce the chrun rate up to 7.47%, thats 5.5% decrease on the churn percentage
# - Applying focusing on at least one (or both) of these two features can reduce the churn from 2.4 to 5.5%

# %% [markdown]
# ### End
